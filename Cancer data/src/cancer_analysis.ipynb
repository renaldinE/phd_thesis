# %%
import matplotlib.pyplot as plt
from matplotlib import colormaps
import pandas as pd
import numpy as np
import json

# %%
# Read data from GLOBOCAN 2022
fp_inc = r'dataset-asr-inc-both-sexes-all-sites-excl-non-melanoma-skin-cancer.csv'
fp_mort = r'dataset-asr-mort-both-sexes-1943-2023-all-sites-excl-non-melanoma-skin-cancer.csv'

df_ = pd.read_csv(fp)

df.rename({c: c.replace(' ', '_').lower() for c in df.columns}, axis=1, inplace=True)
df['population_id']
# Out:
# 0        191
# 1        191
# 2        191
# 3        191
# 4        191
#         ...
# 2103    8263
# 2104    8263
# 2105    8263
# 2106    8263
# 2107    8263
# Name: population_id, Length: 2108, dtype: int64
