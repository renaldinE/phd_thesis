# %%
import matplotlib.pyplot as plt
from matplotlib import colormaps
import pandas as pd
import numpy as np
import json

# %%
# Read data from GLOBOCAN 2022
fp = r'dataset-asr-inc-and-mort-both-sexes-all-sites-excl-non-melanoma-skin-cancer.csv'

df = pd.read_csv(fp)

df.rename({c: c.replace(' ', '_').lower() for c in df.columns}, axis=1, inplace=True)
df.columns
# Out:
# Index(['cancer_id', 'cancer_label', 'population_id', 'country_label', 'sex',
#        'type', 'year', 'asr_(world)', 'crude_rate', 'cumulative_risk',
#        'total'],
#       dtype='object')
